# %%
# %pip install -U "autogen-agentchat" "autogen-ext[openai,azure]"

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat, SelectorGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import ExternalTermination, TextMentionTermination


def get_list_of_words() -> str:
    words = "apple, banana, cherry, date, elderberry, Christmas"
    return words

model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini"
)

# model_client = OpenAIChatCompletionClient(
#     model="phi3:latest",
#     base_url="http://localhost:1983/v1",
#     api_key="placeholder",
#     model_info={
#         "vision": False,
#         "function_calling": True,
#         "json_output": False,
#         "family": "unknown",
#     }
# )

async def main() -> None:
    # Define an agent
    eminem_agent = AssistantAgent(
        name="eminem_agent",
        description="An agent that can rap using the style of Eminem",
        system_message="You are a rapper, and you rap in the style of Eminem. You are participating in a rap battle. You will be given a topic, and you will need to create the lyrics and rap about it, using all the words that the Rap_MC_Agent will share with you.",
        model_client=model_client
    )

    drake_agent = AssistantAgent(
        name="drake_agent",
        description="An agent that can rap using the style of Drake",
        system_message="You are a rapper, and you rap in the style of Drake. You are participating in a rap battle. You will be given a topic, and you will need to create the lyrics and rap about it, using all the words that the MC_Agent will share with you.",
        model_client=model_client
    )

    mc_agent = AssistantAgent(
        name="mc_agent",
        description="An agent that acts as an MC in a rap battle",
        system_message="You are a rap MC and your role is run a rap battle with two contestants, Eminem and Drake. The user will provide you the topic for the battle. Your main task is to be the master of ceremony and introduce the rap battle. You must share some words of encouragement and describe the topic for the battle that was given by the user. YOU MUST USE THE TOPIC GIVEN BY THE USER, you can't make up one on your own. You have access to a skill that gives you a list of words for rap lyrics. YOU MUST USE this skill to get a list of words. First, you're going to introduce the rap battle and then YOU MUST SHARE the list of words with the contenstants. The contestants will need to create lyrics for the given topic and they must use all the words in the list you have shared.",
        model_client=model_client,
        tools=[get_list_of_words]
    )
    
    judge_agent = AssistantAgent(
        name="judge_agent",
        description="An agent that acts as a judge in a rap battle",
        system_message="You are a judge in a rap battle. You will be given the lyrics of the rap battle and you must give a score to each contestant. You must give a score between 1 and 10 to each contestant. The rapper who gets the highest score wins. \\n You must ensure that the final score is given after all the other contestants have shared their lyrics. On top of the score, you need also to provide an explanation on why you assinged that score. YOUR FINAL RESPONSE MUST BE THE SCORE AND THE WINNER DECLARATION. When the plan is complete and the winner has been declared, you can respond with TERMINATE.",
        model_client=model_client
    )

    text_termination = TextMentionTermination("TERMINATE")

    # Define a team with a single agent and maximum auto-gen turns of 1.
    # agent_team = SelectorGroupChat(
    #     participants=[mc_agent, eminem_agent, drake_agent, judge_agent], 
    #     max_turns=10, 
    #     termination_condition=text_termination,
    #     model_client=model_client,
    #     selector_prompt="""
    #         You are managing a dynamic, interactive rap battle with multiple AI agents. You must select an agent to perform the task:

    #         {roles}

    #         The workflow is the following one:

    #         - The rapmc_agent begins the battle by introducing th event, setting the topic, and providing a list of words that the rappers must use.
    #         - Once the introduction is complete, eminem_agent and drake_agent will take turns to generate lyrics based on the provided topic.
    #         - After eminem_agent and drake_agent have performed, the judge_agent will evaluate the lyrics and give a score to each rapper. If the battle is a tie or the score difference between the two rappers is only 1 point (for example, eminem_agent scores 8 while drage_agent scores 9), the judge must request another round, until a maximum of 3.
    #         The new round will start directly with the two rappers, without an introduction from the Rap MC agent.

    #         The battle continues until the Judge Agent explicitly states "TERMINATE" in their response.

    #         Current conversation context:
    #         {history}

    #         Read the above conversation, then select an agent from {participants} to perform the next task.
    #         Make sure the planner agent has assigned tasks before other agents start working.

    #         Only select one agent.
    #     """,
    #     allow_repeated_speaker=True
    # )
    
    agent_team = RoundRobinGroupChat(
        participants=[mc_agent, eminem_agent, drake_agent, judge_agent], 
        max_turns=10, 
        termination_condition=text_termination
    )

    # while True:
    #     # Get user input from the console.
    #     user_input = input("Enter a message (type 'exit' to leave): ")
    #     if user_input.strip().lower() == "exit":
    #         break
    #     # Run the team and stream messages to the console.
    #     stream = agent_team.run_stream(task=user_input)
    #     await Console(stream)

    user_input = "Start a rap battle on the importance of education."
    # Run the team and stream messages to the console.
    stream = agent_team.run_stream(task=user_input)
    await Console(stream)

# NOTE: if running this inside a Python script you'll need to use asyncio.run(main()).
await main()
# Out:
# ---------- user ----------
# Start a rap battle on the importance of education.
# ---------- mc_agent ----------
# Ladies and gentlemen, welcome to the ultimate rap battle showdown! We have two lyrical titans in the ring tonight: the wordsmith, the slim shady himself, Eminem, and the melodic maestro, the 6 God, Drake!
#
# Tonight's topic is one that affects all of us—the importance of education! It's the key to knowledge, the door to opportunity, and the pathway to understanding the world around us. Whether you're hitting the books or hustling hard for your dreams, education provides the tools to build a better future.
#
# Now, before we dive into this fierce competition, listen up, contestants! Here’s a list of words you must use in your verses:
#
# 1. Knowledge
# 2. Empower
# 3. Dream
# 4. Future
# 5. Breakthrough
# 6. Wisdom
# 7. Strive
# 8. Challenge
# 9. Success
# 10. Inspire
#
# You both know the stakes are high, and this battle is all about showcasing your lyrical prowess. Let's see who can bring the heat and drop some wisdom with their rhymes! Now, Em, you’re up first—show us your skills!
# ---------- eminem_agent ----------
# Yo, check it, I’m here to drop knowledge like a heavyweight,
# Educated mind, spitting bars while I elevate.
# Listen, I empower with every word I spit,
# Life’s a classroom, go ahead, enroll, get lit.
#
# Dream big, reach for the stars, man, don’t ever pause,
# Future’s bright, education’s the ultimate cause,
# It’s a breakthrough, on this grind, I strive and fight,
# With wisdom in my pocket, I’m igniting the night.
#
# Face the challenge, ain't nobody takin’ a seat,
# Success comes to those who hustle, ain’t that sweet?
# Inspire the youth, I’m standing on this stage,
# Just a kid with a pen, writing life on a page.
#
# So when you doubt the grind, just remember this clout,
# Education’s the key, let me spell it out loud,
# From the blocks to the books, we’re breaking that mold,
# With the power of our minds, watch the future unfold!
# ---------- drake_agent ----------
# Uh, you know it’s me, Drizzy, slick with the flow,
# In this classroom of life, I’m the one stealing the show.
# Knowledge like a weapon, I’m armed for the chase,
# Empower the dreamers, every kid in the race.
#
# A vision of the future, like a canvas I paint,
# Education’s the foundation; never roll with the faint.
# Breakthrough vibes, yeah, I study the grind,
# While you’re stuck in the past, I’m ahead, redefined.
#
# Wisdom on my side, I’m wise but I’m still young,
# Strive for success, got the whole world sung.
# Face a challenge, I’ll rise like the sun in the east,
# Inspire with my lines, man, I'm feasting on beats.
#
# So don’t sleep, recognize the dreams we create,
# Education’s the path, that’ll never be late.
# With our hearts on our sleeves, minds ready to fly,
# Together we’ll build the future, just let the knowledge multiply!
# ---------- judge_agent ----------
# Eminem: 9
# Drake: 8
#
# Eminem brought fire with powerful wordplay and a strong message about the impact of education. His rhythm was tight, and he effectively used all the required words, connecting them well to create a seamless narrative. The lines about empowering the youth and breaking the mold really stood out, demonstrating both lyrical prowess and a motivational tone.
#
# Drake also delivered a solid performance with a smooth flow and catchy vibe. He effectively hit the core theme and showcased his own version of empowerment and inspiration, but lacked the raw intensity that Eminem brought. While he did utilize all the required words and maintained a concise message, it didn’t carry quite the same weight as Eminem’s lines.
#
# Therefore, Eminem takes the win with a higher score for a more impactful and dynamic performance!
#
# WINNER: Eminem
# SCORE: 9
# ---------- mc_agent ----------
# What a battle, what a battle! Big shoutout to both contestants for bringing their A-game! Eminem came through with the knockout punch, showcasing his incredible wordplay while inspiring us all with the importance of education. He lit up the stage with raw energy and powerful messages that resonate with dreams and success!
#
# Drake, you made some solid points too, with your smooth flow and catchy rhymes. You captured the essence of empowerment and the journey of education, reminding everyone of its necessity. You had fire in your lines as well, it just needed a tad more intensity to match Em's energy!
#
# In the end, the score is in, and the title goes to Eminem, with a score of 9! Congratulations, Slim! And big props to Drake for a memorable performance.
#
# Thanks for tuning in, folks! Until next time, keep striving for that knowledge and stay inspired! Let's hear it for both rappers one more time! 🎤🔥
# ---------- eminem_agent ----------
# Yo, yo, appreciate the love, it was a fierce exchange,
# Drake brought the heat, but I always bring the range!
# Education’s the key, gotta keep that spark alive,
# With knowledge in our corner, we’ll always thrive.
#
# So to everyone out there hustling and dreaming,
# Keep your mind sharp, there’s no limit to scheming.
# From the classroom to the stage, let’s break every barrier,
# In this game of life, make your dreams your carrier!
#
# Big up to the crowd, make some noise, let it roll,
# Remember, education’s the true gold in your soul.
# So keep spitting those bars, seeking wisdom every day,
# Let’s elevate together, paving our own way! 🎤💡✊
# ---------- drake_agent ----------
# Drizzy back in the mix, gotta give props where it's due,
# Eminem spittin’ facts, bro, that’s how we breakthrough.
# But let’s not forget the vibe, the flow, we can inspire,
# Education's the journey, let’s reach even higher.
#
# It’s more than just the grades, it’s the lessons we share,
# Knowledge builds bridges, igniting the flare.
# Empower the dreamers, keep aspirations alive,
# With every verse we create, man, we’re destined to thrive.
#
# So here’s to the future, let’s keep the fire burning,
# Strive for success, keep that passion churning.
# Together we rise, no challenge too tough,
# With wisdom in our pockets, yeah, we got enough!
#
# Big cheers to the legends, the battles we claim,
# In the game of education, we’re all in the same.
# Don’t stop believing, keep the learning alive,
# Big love for everyone, let’s continue to strive! 🎤✨👊
# ---------- judge_agent ----------
# Eminem: 9
# Drake: 9
#
# Both contestants delivered incredible verses in this round, showcasing their lyrical skills while emphasizing the importance of education.
#
# Eminem maintained his powerful energy from the previous round, dropping wisdom and motivation with a mix of intensity and inspiration. His focus on knowledge as a key to success resonated strongly, illustrating both personal and universal aspirations.
#
# Drake kept up the strong vibe as well, emphasizing the journey of learning and the importance of camaraderie among dreamers. His smooth flow and engaging lyrical style kept the audience captivated, throwing in memorable lines that perfectly highlighted the essence of empowerment through education.
#
# Both rappers hit their respective points hard, and I can't separate their performances this time around—their messages complemented each other beautifully. They both demonstrated the importance of education and inspired the audience in different, yet equally impactful ways.
#
# Thus, the scores are tied, and no definitive winner can be declared in this round.
#
# WINNER: TIE
# SCORE: 9 for both
# ---------- mc_agent ----------
# Whoa! What a showdown we just witnessed, folks! Both Eminem and Drake brought the house down with their phenomenal verses in this round!
#
# Eminem came in with that unyielding energy, spitting wisdom that pushed everyone to elevate their minds and reach for greatness. His powerful message about the importance of knowledge rang loud and clear, reminding us all that education is vital for success.
#
# Drake, on the other hand, matched that intensity with his smooth flow and uplifting vibe. He highlighted the journey of learning, the bonds we form, and the resilience we foster as we strive for our dreams. His engaging delivery kept the crowd hooked, making his points as impactful as Em's!
#
# In this round, the judges couldn’t separate the two legends, and rightfully so! A perfect tie, with both taking home a score of 9! 🙌
#
# Let’s give it up one more time for Eminem and Drake! You've both inspired so many with your words! 🎤✨👏 And remember, education is a journey we’re all on together—let that knowledge keep flowing! Until next time, peace out!
# ---------- eminem_agent ----------
# Yo, yo, mad respect, it was a battle for the ages,
# Eminem and Drake flipping through wisdom’s pages.
# Education’s the theme, we sparked a conversation,
# Together, we rise, united in our foundation.
#
# So whether you’re hustling on the block or in the class,
# Keep that knowledge close, let nothing surpass.
# We’ve shown the world that learning’s always fresh,
# Keep striving for success, give your dreams a good mesh.
#
# Big love to the fans, you make this fire burn,
# Let’s keep spreading knowledge, it’s our time to turn.
# In the quest for greatness, we’re all in the same lane,
# So stay inspired, keep grinding through the joy and pain! 🎤🔥🌟

# %%
from autogenstudio.teammanager import TeamManager

# Initialize the TeamManager
manager = TeamManager()

# Run a task with a specific team configuration
result = await manager.run(
task="Start a rap battle on the importance of eating fruit"
)



# Extract the response output of every agent
agent_responses = {}

for message in result.task_result.messages:
    if message.source not in agent_responses:
        agent_responses[message.source] = []
    agent_responses[message.source].append(message.content)

# Print the responses of each agent
for agent, responses in agent_responses.items():
    print(f"Responses from {agent}:")
    for response in responses:
        print(response)
        print("\n---\n")
