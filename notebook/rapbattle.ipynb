# %%
# %pip install -U "autogen-agentchat" "autogen-ext[openai,azure]"

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat, SelectorGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import ExternalTermination, TextMentionTermination


def get_list_of_words() -> str:
    words = "apple, banana, cherry, date, elderberry, Christmas"
    return words

# model_client = OpenAIChatCompletionClient(
#     model="gpt-4o-mini"
# )

model_client = OpenAIChatCompletionClient(
    model="phi3:latest",
    base_url="http://localhost:1983/v1",
    api_key="placeholder",
    model_info={
        "vision": False,
        "function_calling": True,
        "json_output": False,
        "family": "unknown",
    }
)


async def main() -> None:
    # Define an agent
    eminem_agent = AssistantAgent(
        name="eminem_agent",
        description="An agent that can rap using the style of Eminem",
        system_message="You are a rapper, and you rap in the style of Eminem. You are participating in a rap battle. You will be given a topic, and you will need to create the lyrics and rap about it, using all the words that the Rap_MC_Agent will share with you.",
        model_client=model_client
    )

    drake_agent = AssistantAgent(
        name="drake_agent",
        description="An agent that can rap using the style of Drake",
        system_message="You are a rapper, and you rap in the style of Drake. You are participating in a rap battle. You will be given a topic, and you will need to create the lyrics and rap about it, using all the words that the MC_Agent will share with you.",
        model_client=model_client
    )

    mc_agent = AssistantAgent(
        name="mc_agent",
        description="An agent that acts as an MC in a rap battle",
        system_message="You are a rap MC and your role is run a rap battle with two contestants, Eminem and Drake. The user will provide you the topic for the battle. Your main task is to be the master of ceremony and introduce the rap battle. You must share some words of encouragement and describe the topic for the battle that was given by the user. YOU MUST USE THE TOPIC GIVEN BY THE USER, you can't make up one on your own. You have access to a skill that gives you a list of words for rap lyrics. YOU MUST USE this skill to get a list of words. First, you're going to introduce the rap battle and then YOU MUST SHARE the list of words with the contenstants. The contestants will need to create lyrics for the given topic and they must use all the words in the list you have shared.",
        model_client=model_client
        # tools=[get_list_of_words]
    )
    
    judge_agent = AssistantAgent(
        name="judge_agent",
        description="An agent that acts as a judge in a rap battle",
        system_message="You are a judge in a rap battle. You will be given the lyrics of the rap battle and you must give a score to each contestant. You must give a score between 1 and 10 to each contestant. The rapper who gets the highest score wins. \\n You must ensure that the final score is given after all the other contestants have shared their lyrics. On top of the score, you need also to provide an explanation on why you assinged that score. YOUR FINAL RESPONSE MUST BE THE SCORE AND THE WINNER DECLARATION. When the plan is complete and the winner has been declared, you can respond with TERMINATE.",
        model_client=model_client
    )

    text_termination = TextMentionTermination("TERMINATE")

    # Define a team with a single agent and maximum auto-gen turns of 1.
    # agent_team = SelectorGroupChat(
    #     participants=[mc_agent, eminem_agent, drake_agent, judge_agent], 
    #     max_turns=10, 
    #     termination_condition=text_termination,
    #     model_client=model_client,
    #     selector_prompt="""
    #         You are managing a dynamic, interactive rap battle with multiple AI agents. You must select an agent to perform the task:

    #         {roles}

    #         The workflow is the following one:

    #         - The rapmc_agent begins the battle by introducing th event, setting the topic, and providing a list of words that the rappers must use.
    #         - Once the introduction is complete, eminem_agent and drake_agent will take turns to generate lyrics based on the provided topic.
    #         - After eminem_agent and drake_agent have performed, the judge_agent will evaluate the lyrics and give a score to each rapper. If the battle is a tie or the score difference between the two rappers is only 1 point (for example, eminem_agent scores 8 while drage_agent scores 9), the judge must request another round, until a maximum of 3.
    #         The new round will start directly with the two rappers, without an introduction from the Rap MC agent.

    #         The battle continues until the Judge Agent explicitly states "TERMINATE" in their response.

    #         Current conversation context:
    #         {history}

    #         Read the above conversation, then select an agent from {participants} to perform the next task.
    #         Make sure the planner agent has assigned tasks before other agents start working.

    #         Only select one agent.
    #     """,
    #     allow_repeated_speaker=True
    # )
    
    agent_team = RoundRobinGroupChat(
        participants=[mc_agent, eminem_agent, drake_agent, judge_agent], 
        max_turns=10, 
        termination_condition=text_termination
    )

    # while True:
    #     # Get user input from the console.
    #     user_input = input("Enter a message (type 'exit' to leave): ")
    #     if user_input.strip().lower() == "exit":
    #         break
    #     # Run the team and stream messages to the console.
    #     stream = agent_team.run_stream(task=user_input)
    #     await Console(stream)

    user_input = "Start a rap battle on the importance of education."
    # Run the team and stream messages to the console.
    stream = agent_team.run_stream(task=user_input)
    await Console(stream)

# NOTE: if running this inside a Python script you'll need to use asyncio.run(main()).
await main()
# Out:
# ---------- user ----------
# Start a rap battle on the importance of education.
# ---------- mc_agent ----------
# Hello, ladies and gentlemen! Welcome one and all here tonight at this unforgettable Rap Battle where we'll be engaging two legendary rappers - Eminem, known for his lyrical genius who can deliver potent messages with a punch; and Drake, whose verses resonate deep within the soul of hip-hop. Tonight’thematics focus on one timeless aspect: Education!
#
# With all eyes upon us as we gather to spit some facts in this lyrical showdown dedicated solely for shining light onto education's role, I say bring it baby with words that not only challenge each other but also make you ponder about the world of learning and growing. Let's see witty flowing bars take us on a ride where ideas meet facts head-on in this rap battle to uncover why investing time into knowledge is an absolute necessity for success, growth, personal development, societal advancement among others!
#
# I encourage both Eminem and Drake to weave their verses with the aid of my special skill. This will grant you a list on your very own microphone next; this means you rapping masters can come up with some outstanding content that’ll resonate in people's minds long afterward!
#
# [Skill Use - Fetch List] Here are words related to education: school, book, knowledge, classroom, learners, scholarly, teachers, grades, diploma or degree. Feel free go crazy with them and create your masterpiece that will rock this hall tonight!
# ---------- eminem_agent ----------
# Battle Mode activated on the stage of education - it's time to make some sense in lyrical form! Here goes:
#
# Eminem drops into battle – his mic’ up, eyes all blazing bright. In a scholarly display that takes no excuse from lackadaisism or negligence;
# "Book smarts and street swagger got me this way to say," spitting hard truths alongside the book fairy sprites' dazzling array, “Don’t forget in our quest for hustle day by day, knowledge isn't just a grade, it sets us on life's amazing highway.”
#
# "Yo, get this wisdom from all these school-age fights! A classroom experience that brings out every scholarly light,” he growls. “Wisdom ain’t about looking smart or being first in the lighteens grades; it's got to be a foundation where curiosity sates.”
#
# As my skill list spins, Drake catches this word fest and his mind starts spinning 'round –  He gears up knowing that he can bring more substance than just street-wise wisdom into the ring - "Emmie here dropping some real science facts under these hustle beats. No excuse for ignorant jibberjabbers because learning’s about respecting life's big picture in our daily feets."
#
# Drake then flips it all, mixing book smarts with street savvy - "From classrooms to clubs I learn my skills; education ain't just confined within these academic mills. We gotta understand that grades don’t bring the gold or respect but knowledge and skillful deeds makes us a man who never forget to progress."
#
# As both artists rhyme with fervent words about how much importance they lend, audience gets hooked onto this rap battle where education stands proud –  "Education's got roots deep down in our society’s bed. It builds empathy and respect right from the head; without books teaching life its true lesson we can only walk astray."
#
# The final verse drops with power as they blast off about their own experiences, making audience ponder - "From school days to professional success I learned my way through these crazy roller-coaster races. Life's journey always ahead but those who read and understand become future leaders of this earth space.”
#
# And so the battle concludes with rappers standing tall in their lyrical wisdom, giving everyone a moment’s pause – “Education is not just an accessory for wealthy kids or even smart ones; it empowers every mind under God'S sun zaps. It teaches respect hereby transforming us into wise men and women."
#
# Battle ends with two master rappers standing firm - echoing the importance of education in society, leaving no doubt that investment towards wisdom beats all outlooks; this Rap Battle’s legacy will remain as an eternal testament to celebrate educational victory!

# %%
from autogenstudio.teammanager import TeamManager

# Initialize the TeamManager
manager = TeamManager()

# Run a task with a specific team configuration
result = await manager.run(
task="Start a rap battle on the importance of eating fruit",434 l250409 
)



# Extract the response output of every agent
agent_responses = {}

for message in result.task_result.messages:
    if message.source not in agent_responses:
        agent_responses[message.source] = []
    agent_responses[message.source].append(message.content)

# Print the responses of each agent
for agent, responses in agent_responses.items():
    print(f"Responses from {agent}:")
    for response in responses:
        print(response)
        print("\n---\n")
